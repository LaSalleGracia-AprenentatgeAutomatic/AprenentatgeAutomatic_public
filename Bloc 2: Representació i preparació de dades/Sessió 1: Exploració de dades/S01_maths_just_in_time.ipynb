# %% [markdown]
# ## ✋ Exercici a mà: Estadística descriptiva bàsica
#
# Tens les **notes de 7 alumnes** en una prova de matemàtiques:
#
# | Alumne | Nota |
# |:-------|:----:|
# | A | 5 |
# | B | 7 |
# | C | 8 |
# | D | 4 |
# | E | 6 |
# | F | 9 |
# | G | 6 |
#
# ### 1️⃣ Calcula la **mitjana** (promig)
# $\bar{x} = \frac{1}{n}\sum x_i$
# > Escriu el càlcul pas a pas i el resultat final amb una xifra decimal.

# %% [markdown]
# ### Resposta:

# %% [markdown]
# ### 2️⃣ Calcula la **mediana**
# - Ordena les notes de menor a major.
# - Troba el valor central.

# %% [markdown]
# ### Resposta:

# %% [markdown]
# ### 3️⃣ Calcula la **desviació estàndard**
# $\sigma = \sqrt{\frac{1}{n}\sum (x_i - \bar{x})^2}$
# > Mostra almenys una taula amb les restes, els quadrats i la suma total.

# %% [markdown]
# ### Resposta:
# | Nota | $x_i - \bar{x}$ | $(x_i - \bar{x})^2$ |
# |:-----|:------------------:|:----------------------:|
# |     |                    |                        |

# %% [markdown]
# ### ✍️ Reflexió
# - Quina mesura (mitjana, mediana o desviació) et sembla **més informativa** si hi hagués una nota molt baixa (per exemple, un 1)?
# - Què indica una desviació estàndard **alta** o **baixa** en aquest context?
